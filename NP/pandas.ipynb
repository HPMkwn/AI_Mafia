# %%
import pandas as pd

# %%
imdb = pd.read_csv("./imdb_1000.csv")

# %%
imdb.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
bike = pd.read_csv("./bikes.csv", sep=";", parse_dates=['Date'], dayfirst=True, index_col='Date')
bike.head(3)
# Out:
#            Unnamed: 1  ...  Pont_Jacques_Cartier
# Date                   ...
# 2012-01-01      00:00  ...                  27.0
# 2012-01-02      00:00  ...                  21.0
# 2012-01-03      00:00  ...                  15.0
#
# [3 rows x 10 columns]

# %%
imdb.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
imdb.columns.dtype
# Out:
# dtype('O')

# %%
imdb.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
imdb[['title','genre']].head()
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime

# %%
imdb.duration.dtype
# Out:
# dtype('int64')

# %%
imdb.duration.values[:10]
# Out:
# array([142, 175, 200, 152, 154,  96, 161, 201, 195, 139])

# %%
# %matplotlib inline
bikes['Berri1'].plot()

# %%
bikes.plot(figsize=(10,7))

# %%
imdb["title"].str.upper().head()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
imdb['genre'].value_counts()
imdb['genre'].value_counts().plot.bar()

# %%
imdb['genre'].value_counts().plot.pie()

# %%
bikes.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06', '2012-01-07', '2012-01-08',
#                '2012-01-09', '2012-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
bikes.loc['2012-01-01']
# Out:
# Unnamed: 1                     00:00
# Rachel / Papineau                 16
# Berri1                            35
# Maisonneuve_2                     51
# Maisonneuve_1                     38
# Brébeuf                            5
# Parc                              26
# PierDup                           10
# CSC (Côte Sainte-Catherine)        0
# Pont_Jacques_Cartier              27
# Name: 2012-01-01 00:00:00, dtype: object

# %%
bikes.iloc[10]
# Out:
# Unnamed: 1                     00:00
# Rachel / Papineau                194
# Berri1                           273
# Maisonneuve_2                    443
# Maisonneuve_1                    182
# Brébeuf                            7
# Parc                             258
# PierDup                           12
# CSC (Côte Sainte-Catherine)        0
# Pont_Jacques_Cartier              20
# Name: 2012-01-11 00:00:00, dtype: object

# %%
imdb[imdb['genre'] == 'Adventure'].head()
# Out:
#     star_rating  ...                                        actors_list
# 7           8.9  ...  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10          8.8  ...  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14          8.8  ...  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15          8.7  ...  [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# 54          8.5  ...  [u'Michael J. Fox', u'Christopher Lloyd', u'Le...
#
# [5 rows x 6 columns]

# %%
good_movies_condition = (imdb['star_rating'] > 8) & (imdb['duration'] > 130)
imdb[good_movies_condition]['genre'].value_counts()
# Out:
# Drama        36
# Action       20
# Adventure    17
# Crime        13
# Biography    12
# Comedy        6
# Western       6
# Mystery       3
# Animation     1
# Horror        1
# Name: genre, dtype: int64

# %%
bikes['weekday'] = bikes.index.weekday

# %%
bikes.drop('Unnamed: 1', axis=1, inplace=True)

# %%
bikes.drop(bikes.index[0]).head()
# Out:
#             Rachel / Papineau  Berri1  ...  Pont_Jacques_Cartier  weekday
# Date                                   ...
# 2012-01-02                 43      83  ...                  21.0        0
# 2012-01-03                 58     135  ...                  15.0        1
# 2012-01-04                 61     144  ...                  19.0        2
# 2012-01-05                 95     197  ...                  16.0        3
# 2012-01-06                 75     146  ...                  17.0        4
#
# [5 rows x 10 columns]

# %%
genre_groups = imdb.groupby('genre')

# %%
genre_groups.get_group('Crime').head()
# Out:
#     star_rating  ...                                        actors_list
# 0           9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1           9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2           9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4           8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 21          8.7  ...  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
#
# [5 rows x 6 columns]

# %%
genre_groups.aggregate('mean')
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
imdb['new_duration'] = genre_groups['duration'].transform(lambda x:x.mean())

# %%
new_imdb_df = genre_groups.filter(lambda x: x['duration'].mean() > 120)

# %%
weekday_groups = bikes.groupby('weekday')

# %%
weekday_counts = weekday_groups.aggregate(sum)

# %%
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
weekday_counts['Berri1'].plot.bar()
